# %% [markdown]
# Bài 1

# %%
a=int(input("Nhập số nguyên n:"))
print("Số gấp đôi của n là: ",2*a)

# %% [markdown]
# Bài 2

# %%
a=float(input("Nhập chiều rộng a:"))
b=float(input("Nhập chiều dài b:"))
dien_tich_hinh_tron=3.14*a**2
print("Diện tích phần trồng cây là: ",a*b-dien_tich_hinh_tron )
# Out:
# Diện tích phần trồng cây là:  30.23999999999978

# %% [markdown]
# Bài 3

# %%
c=input("Nhập kí tự: ")
print("Đảo ngược kí tự là:",c.swapcase())
# Out:
# Đảo ngược kí tự là: AHFNEJEIjeiddJSD

# %% [markdown]
# Bài 4: Viết chương trình nhập vào một “kí tự”, Kiểm tra xem c có phải là kí tự chữ cái
# không (hoa hoặc thường). Nếu đúng thì in ra “{c} là kí tu alphabet”, nếu sai in ra “{c}
# không phải là kí tự alphabet.

# %%
a = input()
if a.isalpha() == True:
    print(f"{a} là kí tự alphabet")
else:
    print(f"{a} không phải là kí tự alphabet")
# Out:
# jdiddgjrrg là kí tự alphabet

# %% [markdown]
# Bài 5: Nhập vào chữ cái hoa A, in ra chữ cái thường liền trước chữ cái a thường tương
# ứng của A. Xét TH khi c = ‘A’ là đặc biệt.

# %%
a = input()
b = a.swapcase()
print(f"{chr(ord(b)-1)}")
# Out:
# c

# %% [markdown]
# Bài 6. Nhập vào 3 số a, b, c. Kiểm tra xem đây có phải là cạnh của 1 tam giác không,
# nếu đúng thì tính diện tích của tam giác đó, in ra với 1 chữ số phần thập phân, nếu nó
# không phải 3 cạnh của tam giác thì in ra “Khong phai 3 canh cua tam giac”

# %%
a,b,c = map(float, input().split())
p = (a+b+c)/2
if a<b+c and b<a+c and c<a+b:
    print(f"Diện tích tam giác là: {(p*(p-a)*(p-b)*(p-c))**0.5:.1f}")
else:
    print("Khong phải là 3 cạnh của tam giác")
# Out:
# Diện tích tam giác là: 9.8

# %% [markdown]
# Bài 7: Nhập vào một chuỗi gồm các kí tự thường độ dài >=20, in ra chữ cái thứ năm và
# thứ chín của chuỗi này

# %%
a = list(map(str, input().strip()))
print(f"{a[4]} {a[8]}")
# Out:
# o d

# %% [markdown]
# Bài 8: Nhập vào họ tên chủ hộ và chỉ số điện kế tháng trước và chỉ số điện kế tháng này,
# tính tiền điện tháng này cho hộ biết:
# - Từ 0 – 50kWh: 1.984 đồng/kWh
# - Bậc 2: Từ 51 – 100 kWh: 2.050 đồng/kWh
# - Bậc 3: Từ 101 – 200 kWh: 2.380 đồng/kWh
# - Bậc 4: Từ 201 – 300 kWh: 2.998 đồng/kWh
# - Bậc 5: Từ 301 – 400 kWh: 3.350 đồng/kWh
# - Bậc 6: Từ 401 trở đi kWh: 3.460 đồng/kWh

# %%
a = input("Họ tên là: ")
c = int(input("Chỉ số tháng trước: "))
b = int(input("Chỉ số tháng này: "))
print(f"Họ tên là: {a}")
if b-c <= 50:
    print(f"Số tiền phải trả là: {round((b-c)*1984*108/100)}")
elif b-c > 50 and b-c <=100:
    print(f"Số tiền phải trả là: {round((50*1984+(b-c-50)*2050)*108/100)}")
elif b-c>100 and b-c <=200:
    print(f"Số tiền phải trả là: {round((50*1984+50*2050+(b-c-100)*2380)*108/100)}")    
elif b-c>200 and b-c <=300:
    print(f"Số tiền phải trả là: {round((50*1984+50*2050+100*2380+(b-c-200)*2998)*108/100)}")
elif b-c>300 and b-c <=400:
    print(f"Số tiền phải trả là: {round((50*1984+50*2050+100*2380+100*2998+(b-c-300)*3350)*108/100)}")
elif b-c>400:   
    print(f"Số tiền phải trả là: {round((50*1984+50*2050+100*2380+100*2998+100*3350+(b-c-400)*3460)*108/100)}")
# Out:
# Họ tên là: nam
# Số tiền phải trả là: 426038
