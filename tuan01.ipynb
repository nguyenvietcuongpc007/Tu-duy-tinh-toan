# %% [markdown]
# Bai 1

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# Bai 2

# %%
a=input("Nhap ten cua ban:")
print("ten cua ban la:",a)
# Out:
# ten cua ban la: 1

# %% [markdown]
# Bai 3

# %%
a=int(input("Nhap so nguyen a:"))
b=int(input("Nhap so nguyen b:"))
print("Tong",a+b,"Hieu",a-b,"Tich",a*b,"Phan nguyen",a//b,"Phan du",a%b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 a=input(int("Nhap so nguyen a:"))
#       2 b=input(int("Nhap so nguyen b:"))
#       3 print("Tong",a+b,"Hieu",a-b,"Tich",a*b,"Phan nguyen",a//b,"Phan du",a%b)
#
# ValueError: invalid literal for int() with base 10: 'Nhap so nguyen a:'
